# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df=pd.read_csv('MindReader2.csv')
df.head()
# Out:
#   date      mode                      experts   username   result  score  \
# 0    0  original  [u'varTreePY', u'varTreeY']  anonymous  Restart      1
# 1    0  original  [u'varTreePY', u'varTreeY']       mpla  Restart      1
# 2    0  original  [u'varTreePY', u'varTreeY']  anonymous    Loser    -40
# 3    0  original  [u'varTreePY', u'varTreeY']      kinet    Loser     -9
# 4    0  original  [u'varTreePY', u'varTreeY']  anonymous  Restart     -7
#
#               ip                                        movesPlayer  \
# 0  46.190.74.118                                               [3L]
# 1  46.190.74.118                                               [3L]
# 2  46.190.74.118  [1L, 1L, 1L, 0L, 1L, 1L, 0L, 0L, 1L, 1L, 0L, 1...
# 3  46.190.80.111  [1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1...
# 4  46.190.85.246  [1L, 1L, 0L, 1L, 0L, 0L, 0L, 1L, 0L, 0L, 1L, 0...
#
#                                            movesComp  \
# 0                                               [3L]
# 1                                               [3L]
# 2  [1L, 0L, 0L, 1L, 0L, 1L, 1L, 0L, 1L, 1L, 0L, 0...
# 3  [1L, 0L, 1L, 1L, 0L, 1L, 1L, 1L, 1L, 1L, 1L, 1...
# 4  [0L, 0L, 1L, 1L, 0L, 0L, 0L, 0L, 1L, 1L, 1L, 0...
#
#                                                times
# 0                                   [1453339020246L]
# 1                                   [1453339031052L]
# 2  [1453339051559L, 1453339053309L, 1453339055013...
# 3  [1453397697937L, 1453397702224L, 1453397705097...
# 4  [1453338720283L, 1453338722833L, 1453338724208...

# %%
df.groupby('result').count()
# Out:
#          date  mode  experts  username  score    ip  movesPlayer  movesComp  \
# result
# Cheater    48    48       48        48     48    48           48         48
# Hacker     78    78       78        78     78    78           78         78
# Loser    3111  3111     3111      3111   3111  3111         3111       3111
# Restart  1179  1179     1179      1179   1179  1179         1179       1179
# TimeOut   734   734      734       734    734   734          734        734
# Winner   1533  1533     1533      1532   1533  1533         1533       1533
#
#          times
# result
# Cheater     48
# Hacker      78
# Loser     3111
# Restart   1179
# TimeOut    734
# Winner    1533

# %%
df[df['username']=='boris']
# Out:
#                             date     mode                      experts  \
# 870   2016-02-04 07:50:21.167700  timed.5  [u'varTreePY', u'varTreeY']
# 874   2016-02-07 15:08:22.288870  timed.5  [u'varTreePY', u'varTreeY']
# 875   2016-02-07 15:08:53.941220  timed.5  [u'varTreePY', u'varTreeY']
# 876   2016-02-07 15:09:21.687530  timed.5  [u'varTreePY', u'varTreeY']
# 877   2016-02-07 15:09:54.235100  timed.5  [u'varTreePY', u'varTreeY']
# 878   2016-02-07 15:11:02.540760  timed.5  [u'varTreePY', u'varTreeY']
# 879   2016-02-07 15:11:35.561510  timed.5  [u'varTreePY', u'varTreeY']
# 880   2016-02-07 15:13:27.361650  timed.5  [u'varTreePY', u'varTreeY']
# 881   2016-02-07 15:19:35.820380  timed.5  [u'varTreePY', u'varTreeY']
# 882   2016-02-07 15:20:30.513680  timed.5  [u'varTreePY', u'varTreeY']
# 883   2016-02-07 15:24:37.019770  timed.5  [u'varTreePY', u'varTreeY']
# 884   2016-02-07 15:25:21.776790  timed.5  [u'varTreePY', u'varTreeY']
# 885   2016-02-07 15:26:26.009420  timed.5  [u'varTreePY', u'varTreeY']
# 886   2016-02-07 15:26:59.356500  timed.5  [u'varTreePY', u'varTreeY']
# 887   2016-02-07 15:27:33.153620  timed.5  [u'varTreePY', u'varTreeY']
# 888   2016-02-07 15:28:05.032960  timed.5  [u'varTreePY', u'varTreeY']
# 889   2016-02-07 15:28:36.322850  timed.5  [u'varTreePY', u'varTreeY']
# 890   2016-02-07 15:29:08.892780  timed.5  [u'varTreePY', u'varTreeY']
# 891   2016-02-07 15:29:39.929810  timed.5  [u'varTreePY', u'varTreeY']
# 892   2016-02-07 15:30:12.194620  timed.5  [u'varTreePY', u'varTreeY']
# 893   2016-02-07 15:30:46.601000  timed.5  [u'varTreePY', u'varTreeY']
# 894   2016-02-07 15:31:33.519580  timed.5  [u'varTreePY', u'varTreeY']
# 895   2016-02-07 15:32:07.362480  timed.5  [u'varTreePY', u'varTreeY']
# 896   2016-02-07 15:32:39.436220  timed.5  [u'varTreePY', u'varTreeY']
# 897   2016-02-07 15:33:12.460700  timed.5  [u'varTreePY', u'varTreeY']
# 898   2016-02-07 15:33:44.355210  timed.5  [u'varTreePY', u'varTreeY']
# 899   2016-02-07 15:34:17.642850  timed.5  [u'varTreePY', u'varTreeY']
# 900   2016-02-07 15:34:52.362240  timed.5  [u'varTreePY', u'varTreeY']
# 901   2016-02-07 15:35:26.460390  timed.5  [u'varTreePY', u'varTreeY']
# 902   2016-02-07 15:35:58.782030  timed.5  [u'varTreePY', u'varTreeY']
# ...                          ...      ...                          ...
# 6441  2016-02-08 22:47:27.321730  timed.5  [u'varTreePY', u'varTreeY']
# 6442  2016-02-08 22:47:57.808080  timed.5  [u'varTreePY', u'varTreeY']
# 6443  2016-02-08 22:48:28.460270  timed.5  [u'varTreePY', u'varTreeY']
# 6444  2016-02-08 22:49:00.476950  timed.5  [u'varTreePY', u'varTreeY']
# 6445  2016-02-08 22:49:32.310190  timed.5  [u'varTreePY', u'varTreeY']
# 6446  2016-02-08 22:50:05.055800  timed.5  [u'varTreePY', u'varTreeY']
# 6447  2016-02-08 22:50:34.465760  timed.5  [u'varTreePY', u'varTreeY']
# 6448  2016-02-08 22:51:06.498620  timed.5  [u'varTreePY', u'varTreeY']
# 6449  2016-02-08 22:51:39.124150  timed.5  [u'varTreePY', u'varTreeY']
# 6450  2016-02-08 22:52:09.826250  timed.5  [u'varTreePY', u'varTreeY']
# 6451  2016-02-08 22:52:41.677640  timed.5  [u'varTreePY', u'varTreeY']
# 6452  2016-02-08 22:53:11.682170  timed.5  [u'varTreePY', u'varTreeY']
# 6453  2016-02-08 22:53:41.608750  timed.5  [u'varTreePY', u'varTreeY']
# 6454  2016-02-08 22:54:13.037980  timed.5  [u'varTreePY', u'varTreeY']
# 6455  2016-02-08 22:54:44.744030  timed.5  [u'varTreePY', u'varTreeY']
# 6456  2016-02-08 22:55:15.345040  timed.5  [u'varTreePY', u'varTreeY']
# 6457  2016-02-08 22:55:47.060600  timed.5  [u'varTreePY', u'varTreeY']
# 6458  2016-02-08 22:56:16.471850  timed.5  [u'varTreePY', u'varTreeY']
# 6459  2016-02-08 22:56:47.234470  timed.5  [u'varTreePY', u'varTreeY']
# 6460  2016-02-08 22:57:20.584840  timed.5  [u'varTreePY', u'varTreeY']
# 6461  2016-02-08 22:57:52.567420  timed.5  [u'varTreePY', u'varTreeY']
# 6462  2016-02-08 22:58:23.203860  timed.5  [u'varTreePY', u'varTreeY']
# 6463  2016-02-08 22:58:55.129430  timed.5  [u'varTreePY', u'varTreeY']
# 6464  2016-02-08 22:59:26.277270  timed.5  [u'varTreePY', u'varTreeY']
# 6465  2016-02-08 22:59:59.186820  timed.5  [u'varTreePY', u'varTreeY']
# 6466  2016-02-12 05:14:11.173460  timed.5  [u'varTreePY', u'varTreeY']
# 6470  2016-02-12 05:15:40.287630  timed.5  [u'varTreePY', u'varTreeY']
# 6471  2016-02-12 05:17:24.727010  timed.5  [u'varTreePY', u'varTreeY']
# 6472  2016-02-12 05:17:55.921580  timed.5  [u'varTreePY', u'varTreeY']
# 6473  2016-02-12 05:18:05.315110  timed.5  [u'varTreePY', u'varTreeY']
#
#      username   result  score              ip  \
# 870     boris  TimeOut     -1   82.166.224.52
# 874     boris  TimeOut      1   82.166.224.52
# 875     boris  TimeOut      1   82.166.224.52
# 876     boris    Loser     -5   82.166.224.52
# 877     boris    Loser    -14   82.166.224.52
# 878     boris   Winner      4   82.166.224.52
# 879     boris   Winner     18   82.166.224.52
# 880     boris   Winner     19   82.166.224.52
# 881     boris  TimeOut      1   82.166.224.52
# 882     boris    Loser    -18   82.166.224.52
# 883     boris   Winner     12   82.166.224.52
# 884     boris   Winner     32   82.166.224.52
# 885     boris    Loser    -21   82.166.224.52
# 886     boris   Winner      9   82.166.224.52
# 887     boris   Winner      3   82.166.224.52
# 888     boris    Loser    -10   82.166.224.52
# 889     boris   Winner     19   82.166.224.52
# 890     boris    Loser     -9   82.166.224.52
# 891     boris   Winner     21   82.166.224.52
# 892     boris    Loser    -10   82.166.224.52
# 893     boris    Loser     -6   82.166.224.52
# 894     boris   Winner     20   82.166.224.52
# 895     boris    Loser     -9   82.166.224.52
# 896     boris   Winner     21   82.166.224.52
# 897     boris   Winner     13   82.166.224.52
# 898     boris   Winner     25   82.166.224.52
# 899     boris   Winner     15   82.166.224.52
# 900     boris    Loser     -2   82.166.224.52
# 901     boris    Loser     -5   82.166.224.52
# 902     boris   Winner     17   82.166.224.52
# ...       ...      ...    ...             ...
# 6441    boris   Winner     11  109.65.142.172
# 6442    boris    Loser    -18  109.65.142.172
# 6443    boris   Winner     15  109.65.142.172
# 6444    boris    Loser     -6  109.65.142.172
# 6445    boris    Loser     -9  109.65.142.172
# 6446    boris    Loser     -1  109.65.142.172
# 6447    boris   Winner     23  109.65.142.172
# 6448    boris    Loser     -9  109.65.142.172
# 6449    boris    Loser     -2  109.65.142.172
# 6450    boris    Loser    -18  109.65.142.172
# 6451    boris   Winner      5  109.65.142.172
# 6452    boris    Loser    -19  109.65.142.172
# 6453    boris   Winner     26  109.65.142.172
# 6454    boris    Loser    -18  109.65.142.172
# 6455    boris    Loser    -14  109.65.142.172
# 6456    boris   Winner     14  109.65.142.172
# 6457    boris   Winner      9  109.65.142.172
# 6458    boris    Loser    -27  109.65.142.172
# 6459    boris   Winner     22  109.65.142.172
# 6460    boris   Winner      2  109.65.142.172
# 6461    boris    Loser    -11  109.65.142.172
# 6462    boris    Loser    -26  109.65.142.172
# 6463    boris    Loser     -9  109.65.142.172
# 6464    boris   Winner     12  109.65.142.172
# 6465    boris   Winner      4  109.65.142.172
# 6466    boris   Winner     26  109.65.142.172
# 6470    boris   Winner     13  109.65.142.172
# 6471    boris    Loser    -14  109.65.142.172
# 6472    boris  TimeOut     10  109.65.142.172
# 6473    boris   Winner     13  109.65.142.172
#
#                                             movesPlayer  \
# 870   [0L, 1L, 0L, 1L, 0L, 0L, 0L, 0L, 0L, 1L, 0L, 0...
# 874                                                [3L]
# 875                                                [3L]
# 876   [0L, 0L, 0L, 0L, 0L, 0L, 1L, 1L, 0L, 1L, 0L, 0...
# 877   [1L, 1L, 1L, 1L, 1L, 1L, 0L, 1L, 0L, 0L, 0L, 1...
# 878   [1L, 0L, 0L, 1L, 1L, 1L, 0L, 1L, 0L, 0L, 1L, 1...
# 879   [0L, 0L, 1L, 0L, 0L, 1L, 0L, 1L, 0L, 1L, 1L, 1...
# 880   [0L, 0L, 1L, 0L, 0L, 1L, 1L, 1L, 1L, 0L, 1L, 1...
# 881                                                [3L]
# 882   [1L, 1L, 1L, 0L, 0L, 0L, 1L, 1L, 1L, 1L, 0L, 0...
# 883   [0L, 1L, 1L, 0L, 1L, 1L, 1L, 0L, 0L, 1L, 0L, 1...
# 884   [0L, 1L, 1L, 0L, 1L, 1L, 1L, 0L, 0L, 1L, 0L, 1...
# 885   [0L, 1L, 1L, 0L, 1L, 1L, 1L, 0L, 0L, 1L, 0L, 1...
# 886   [0L, 1L, 1L, 0L, 1L, 1L, 1L, 0L, 1L, 1L, 0L, 1...
# 887   [0L, 1L, 1L, 0L, 1L, 1L, 1L, 0L, 1L, 1L, 0L, 1...
# 888   [0L, 1L, 1L, 1L, 1L, 1L, 0L, 0L, 0L, 1L, 0L, 0...
# 889   [0L, 1L, 0L, 0L, 1L, 1L, 1L, 0L, 0L, 1L, 0L, 1...
# 890   [0L, 1L, 1L, 1L, 1L, 1L, 1L, 0L, 0L, 1L, 0L, 1...
# 891   [0L, 0L, 1L, 0L, 0L, 1L, 1L, 0L, 1L, 1L, 0L, 1...
# 892   [0L, 1L, 1L, 0L, 1L, 1L, 1L, 0L, 0L, 1L, 0L, 1...
# 893   [0L, 1L, 1L, 0L, 1L, 1L, 1L, 0L, 0L, 0L, 0L, 1...
# 894   [0L, 1L, 1L, 0L, 1L, 1L, 1L, 0L, 0L, 1L, 0L, 1...
# 895   [0L, 1L, 1L, 0L, 1L, 0L, 1L, 0L, 0L, 1L, 0L, 1...
# 896   [0L, 1L, 1L, 0L, 1L, 1L, 1L, 0L, 0L, 1L, 0L, 0...
# 897   [0L, 1L, 1L, 0L, 1L, 1L, 0L, 0L, 0L, 1L, 0L, 1...
# 898   [0L, 1L, 0L, 0L, 0L, 1L, 1L, 0L, 0L, 1L, 0L, 0...
# 899   [0L, 1L, 1L, 0L, 1L, 0L, 1L, 0L, 0L, 1L, 0L, 1...
# 900   [0L, 1L, 1L, 0L, 1L, 1L, 0L, 0L, 0L, 1L, 0L, 0...
# 901   [0L, 0L, 1L, 0L, 1L, 1L, 1L, 0L, 0L, 1L, 0L, 1...
# 902   [0L, 1L, 1L, 0L, 1L, 1L, 0L, 0L, 0L, 1L, 0L, 1...
# ...                                                 ...
# 6441  [0L, 1L, 1L, 1L, 1L, 0L, 1L, 0L, 0L, 0L, 1L, 0...
# 6442  [1L, 1L, 0L, 1L, 0L, 0L, 1L, 0L, 0L, 1L, 1L, 0...
# 6443  [0L, 1L, 0L, 1L, 0L, 1L, 1L, 0L, 0L, 1L, 0L, 0...
# 6444  [0L, 0L, 1L, 0L, 1L, 1L, 1L, 0L, 0L, 1L, 1L, 0...
# 6445  [0L, 0L, 0L, 1L, 1L, 0L, 1L, 1L, 0L, 1L, 0L, 1...
# 6446  [0L, 0L, 0L, 0L, 1L, 1L, 0L, 0L, 1L, 0L, 0L, 0...
# 6447  [1L, 0L, 1L, 1L, 1L, 0L, 0L, 1L, 0L, 1L, 1L, 1...
# 6448  [0L, 1L, 0L, 0L, 0L, 1L, 1L, 1L, 1L, 1L, 0L, 1...
# 6449  [1L, 0L, 1L, 0L, 1L, 1L, 1L, 1L, 0L, 0L, 1L, 0...
# 6450  [0L, 0L, 0L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 0...
# 6451  [1L, 0L, 1L, 1L, 1L, 0L, 1L, 0L, 0L, 1L, 0L, 0...
# 6452  [0L, 0L, 0L, 1L, 0L, 1L, 0L, 0L, 1L, 1L, 0L, 1...
# 6453  [0L, 0L, 0L, 1L, 0L, 1L, 1L, 1L, 0L, 0L, 1L, 0...
# 6454  [1L, 0L, 1L, 0L, 0L, 0L, 1L, 1L, 1L, 0L, 0L, 1...
# 6455  [0L, 1L, 0L, 1L, 0L, 0L, 1L, 0L, 0L, 0L, 1L, 1...
# 6456  [1L, 1L, 1L, 1L, 1L, 0L, 1L, 0L, 0L, 1L, 1L, 1...
# 6457  [1L, 0L, 0L, 0L, 1L, 1L, 1L, 1L, 1L, 0L, 1L, 0...
# 6458  [0L, 1L, 0L, 0L, 0L, 0L, 1L, 1L, 0L, 1L, 0L, 1...
# 6459  [0L, 1L, 1L, 0L, 0L, 0L, 0L, 0L, 1L, 0L, 1L, 0...
# 6460  [1L, 1L, 1L, 1L, 0L, 0L, 0L, 0L, 1L, 0L, 1L, 1...
# 6461  [1L, 0L, 0L, 0L, 0L, 1L, 0L, 0L, 1L, 0L, 1L, 1...
# 6462  [1L, 0L, 0L, 1L, 0L, 1L, 0L, 0L, 0L, 0L, 1L, 1...
# 6463  [1L, 1L, 0L, 0L, 1L, 0L, 1L, 0L, 0L, 1L, 0L, 1...
# 6464  [1L, 0L, 1L, 0L, 0L, 1L, 0L, 1L, 0L, 1L, 1L, 1...
# 6465  [1L, 1L, 0L, 1L, 0L, 1L, 0L, 1L, 1L, 1L, 1L, 1...
# 6466  [0L, 1L, 1L, 1L, 0L, 1L, 0L, 1L, 0L, 1L, 1L, 1...
# 6470  [0L, 0L, 0L, 1L, 0L, 0L, 1L, 1L, 1L, 1L, 1L, 0...
# 6471  [1L, 1L, 1L, 0L, 0L, 1L, 1L, 0L, 1L, 0L, 0L, 1...
# 6472  [1L, 1L, 1L, 1L, 1L, 1L, 1L, 0L, 0L, 1L, 0L, 0...
# 6473  [0L, 1L, 0L, 1L, 0L, 0L, 1L, 0L, 1L, 1L, 1L, 1...
#
#                                               movesComp  \
# 870   [0L, 1L, 0L, 1L, 1L, 1L, 1L, 1L, 0L, 0L, 0L, 1...
# 874                                                [3L]
# 875                                                [3L]
# 876   [0L, 0L, 0L, 0L, 0L, 0L, 0L, 1L, 1L, 0L, 1L, 0...
# 877   [0L, 1L, 1L, 1L, 0L, 1L, 1L, 1L, 1L, 0L, 0L, 0...
# 878   [1L, 1L, 0L, 0L, 1L, 1L, 0L, 0L, 0L, 1L, 1L, 1...
# 879   [1L, 1L, 0L, 0L, 1L, 1L, 0L, 0L, 0L, 1L, 0L, 0...
# 880   [1L, 1L, 0L, 1L, 1L, 1L, 1L, 1L, 0L, 0L, 0L, 0...
# 881                                                [3L]
# 882   [0L, 0L, 1L, 1L, 0L, 0L, 0L, 0L, 1L, 0L, 1L, 0...
# 883   [1L, 1L, 0L, 1L, 1L, 0L, 0L, 0L, 1L, 1L, 1L, 1...
# 884   [1L, 1L, 0L, 0L, 0L, 0L, 0L, 1L, 1L, 0L, 1L, 1...
# 885   [0L, 1L, 0L, 1L, 1L, 1L, 0L, 0L, 0L, 1L, 0L, 1...
# 886   [1L, 0L, 0L, 0L, 1L, 0L, 1L, 0L, 1L, 0L, 0L, 1...
# 887   [1L, 1L, 1L, 0L, 1L, 0L, 1L, 0L, 0L, 0L, 1L, 0...
# 888   [0L, 1L, 0L, 1L, 1L, 1L, 1L, 0L, 0L, 0L, 1L, 1...
# 889   [1L, 0L, 0L, 1L, 1L, 0L, 0L, 0L, 1L, 0L, 0L, 1...
# 890   [0L, 1L, 0L, 0L, 0L, 1L, 1L, 1L, 0L, 0L, 1L, 0...
# 891   [1L, 1L, 0L, 0L, 0L, 1L, 1L, 1L, 1L, 0L, 1L, 1...
# 892   [0L, 0L, 0L, 0L, 0L, 1L, 0L, 0L, 1L, 0L, 0L, 1...
# 893   [0L, 0L, 0L, 1L, 0L, 1L, 1L, 0L, 0L, 1L, 1L, 0...
# 894   [1L, 1L, 0L, 0L, 0L, 0L, 1L, 0L, 1L, 0L, 1L, 0...
# 895   [1L, 0L, 1L, 1L, 1L, 0L, 0L, 1L, 1L, 0L, 0L, 1...
# 896   [1L, 1L, 0L, 0L, 1L, 0L, 0L, 1L, 1L, 1L, 0L, 1...
# 897   [1L, 0L, 1L, 0L, 1L, 1L, 1L, 1L, 1L, 0L, 1L, 1...
# 898   [1L, 1L, 0L, 1L, 0L, 0L, 1L, 1L, 1L, 0L, 0L, 0...
# 899   [0L, 1L, 1L, 1L, 1L, 1L, 1L, 0L, 1L, 0L, 0L, 1...
# 900   [0L, 1L, 1L, 1L, 0L, 0L, 0L, 1L, 1L, 1L, 0L, 0...
# 901   [0L, 1L, 1L, 0L, 1L, 1L, 1L, 0L, 1L, 0L, 0L, 1...
# 902   [1L, 1L, 1L, 1L, 1L, 0L, 0L, 0L, 1L, 1L, 0L, 0...
# ...                                                 ...
# 6441  [1L, 0L, 0L, 0L, 1L, 1L, 1L, 0L, 1L, 0L, 1L, 1...
# 6442  [1L, 1L, 0L, 1L, 0L, 0L, 1L, 0L, 1L, 1L, 0L, 0...
# 6443  [0L, 1L, 0L, 0L, 0L, 0L, 0L, 0L, 1L, 1L, 0L, 1...
# 6444  [1L, 1L, 0L, 0L, 1L, 0L, 0L, 1L, 0L, 0L, 0L, 1...
# 6445  [1L, 0L, 1L, 1L, 1L, 1L, 0L, 1L, 0L, 1L, 0L, 1...
# 6446  [1L, 0L, 0L, 0L, 0L, 1L, 1L, 0L, 0L, 1L, 0L, 0...
# 6447  [1L, 1L, 1L, 0L, 0L, 0L, 0L, 1L, 0L, 0L, 0L, 0...
# 6448  [0L, 1L, 1L, 1L, 1L, 1L, 0L, 1L, 0L, 1L, 1L, 0...
# 6449  [1L, 1L, 1L, 1L, 1L, 0L, 1L, 1L, 0L, 1L, 0L, 0...
# 6450  [0L, 1L, 0L, 0L, 1L, 0L, 1L, 1L, 1L, 1L, 1L, 1...
# 6451  [1L, 1L, 1L, 1L, 0L, 1L, 1L, 0L, 0L, 0L, 0L, 1...
# 6452  [1L, 1L, 1L, 0L, 0L, 0L, 0L, 1L, 0L, 0L, 1L, 1...
# 6453  [0L, 0L, 1L, 0L, 0L, 1L, 0L, 1L, 1L, 0L, 0L, 1...
# 6454  [1L, 1L, 0L, 0L, 1L, 1L, 0L, 0L, 0L, 0L, 0L, 0...
# 6455  [0L, 1L, 0L, 1L, 0L, 1L, 1L, 0L, 1L, 1L, 0L, 0...
# 6456  [1L, 1L, 1L, 0L, 1L, 1L, 0L, 0L, 1L, 1L, 0L, 1...
# 6457  [1L, 1L, 1L, 1L, 0L, 1L, 1L, 0L, 1L, 1L, 0L, 1...
# 6458  [1L, 0L, 1L, 1L, 1L, 1L, 1L, 0L, 1L, 1L, 0L, 1...
# 6459  [1L, 0L, 1L, 1L, 1L, 1L, 0L, 0L, 0L, 1L, 1L, 1...
# 6460  [0L, 0L, 1L, 1L, 1L, 0L, 0L, 0L, 0L, 1L, 0L, 1...
# 6461  [1L, 0L, 1L, 0L, 0L, 1L, 1L, 0L, 0L, 1L, 0L, 0...
# 6462  [1L, 0L, 1L, 1L, 0L, 1L, 0L, 1L, 1L, 1L, 1L, 1...
# 6463  [0L, 1L, 0L, 0L, 0L, 0L, 0L, 0L, 1L, 1L, 1L, 1...
# 6464  [0L, 0L, 0L, 0L, 1L, 0L, 0L, 1L, 0L, 1L, 0L, 0...
# 6465  [1L, 1L, 1L, 0L, 0L, 1L, 0L, 1L, 0L, 0L, 0L, 0...
# 6466  [0L, 1L, 0L, 0L, 1L, 0L, 0L, 1L, 1L, 1L, 0L, 0...
# 6470  [0L, 0L, 0L, 0L, 0L, 0L, 1L, 0L, 0L, 1L, 1L, 1...
# 6471  [1L, 0L, 1L, 0L, 1L, 0L, 1L, 1L, 0L, 0L, 0L, 0...
# 6472  [1L, 1L, 1L, 0L, 0L, 1L, 1L, 1L, 0L, 0L, 1L, 1...
# 6473  [0L, 0L, 0L, 0L, 0L, 1L, 1L, 0L, 1L, 0L, 0L, 0...
#
#                                                   times
# 870   [0L, 41L, 139L, 64L, 54L, 34L, 19L, 18L, 18L, ...
# 874                                                [0L]
# 875                                                [0L]
# 876   [0L, 5L, 7L, 5L, 3L, 8L, 3L, 11L, 10L, 7L, 10L...
# 877   [0L, 9L, 8L, 4L, 6L, 9L, 3L, 7L, 6L, 7L, 11L, ...
# 878   [0L, 6L, 8L, 2L, 6L, 5L, 12L, 2L, 9L, 3L, 8L, ...
# 879   [0L, 115L, 9L, 9L, 9L, 11L, 9L, 4L, 5L, 11L, 3...
# 880   [0L, 5L, 5L, 8L, 11L, 6L, 12L, 9L, 3L, 6L, 11L...
# 881                                                [0L]
# 882   [0L, 7L, 5L, 11L, 3L, 11L, 10L, 7L, 8L, 5L, 10...
# 883   [0L, 9L, 3L, 11L, 6L, 2L, 9L, 11L, 4L, 2L, 3L,...
# 884   [0L, 6L, 2L, 13L, 10L, 6L, 12L, 9L, 10L, 7L, 6...
# 885   [0L, 9L, 2L, 6L, 3L, 8L, 10L, 4L, 12L, 8L, 12L...
# 886   [0L, 7L, 4L, 2L, 2L, 4L, 4L, 12L, 9L, 4L, 11L,...
# 887   [0L, 10L, 6L, 11L, 12L, 7L, 3L, 6L, 10L, 3L, 7...
# 888   [0L, 8L, 9L, 8L, 8L, 6L, 5L, 6L, 9L, 4L, 11L, ...
# 889   [0L, 6L, 10L, 3L, 9L, 3L, 10L, 3L, 5L, 6L, 4L,...
# 890   [0L, 10L, 10L, 6L, 6L, 6L, 6L, 7L, 7L, 2L, 10L...
# 891   [0L, 9L, 8L, 8L, 9L, 8L, 5L, 9L, 10L, 3L, 9L, ...
# 892   [0L, 2L, 11L, 7L, 9L, 12L, 9L, 12L, 3L, 12L, 1...
# 893   [0L, 13L, 10L, 6L, 11L, 6L, 5L, 5L, 9L, 9L, 14...
# 894   [0L, 5L, 6L, 11L, 8L, 12L, 12L, 3L, 2L, 9L, 8L...
# 895   [0L, 10L, 11L, 11L, 10L, 8L, 5L, 13L, 4L, 7L, ...
# 896   [0L, 10L, 3L, 4L, 4L, 3L, 9L, 11L, 8L, 13L, 4L...
# 897   [0L, 6L, 7L, 7L, 11L, 10L, 4L, 7L, 6L, 10L, 12...
# 898   [0L, 11L, 12L, 3L, 11L, 2L, 7L, 7L, 11L, 9L, 6...
# 899   [0L, 7L, 3L, 11L, 7L, 8L, 12L, 2L, 7L, 4L, 5L,...
# 900   [0L, 6L, 9L, 8L, 6L, 7L, 3L, 5L, 11L, 11L, 13L...
# 901   [0L, 10L, 7L, 5L, 9L, 9L, 10L, 2L, 3L, 7L, 5L,...
# 902   [0L, 8L, 6L, 3L, 5L, 14L, 4L, 6L, 2L, 6L, 8L, ...
# ...                                                 ...
# 6441  [0L, 11L, 11L, 9L, 8L, 9L, 11L, 9L, 6L, 7L, 5L...
# 6442  [0L, 7L, 7L, 4L, 12L, 9L, 6L, 5L, 5L, 9L, 3L, ...
# 6443  [0L, 8L, 7L, 11L, 4L, 4L, 12L, 3L, 9L, 12L, 4L...
# 6444  [0L, 9L, 3L, 6L, 11L, 7L, 8L, 6L, 6L, 6L, 12L,...
# 6445  [0L, 6L, 10L, 12L, 3L, 4L, 11L, 11L, 9L, 4L, 8...
# 6446  [0L, 5L, 5L, 3L, 7L, 6L, 7L, 6L, 9L, 3L, 14L, ...
# 6447  [0L, 9L, 8L, 7L, 3L, 5L, 5L, 12L, 10L, 6L, 5L,...
# 6448  [0L, 8L, 3L, 7L, 3L, 8L, 6L, 10L, 8L, 7L, 7L, ...
# 6449  [0L, 9L, 2L, 11L, 7L, 3L, 6L, 11L, 6L, 8L, 6L,...
# 6450  [0L, 12L, 10L, 13L, 4L, 4L, 8L, 3L, 6L, 5L, 6L...
# 6451  [0L, 3L, 9L, 6L, 7L, 3L, 11L, 10L, 8L, 10L, 3L...
# 6452  [0L, 10L, 7L, 12L, 11L, 7L, 6L, 11L, 9L, 9L, 4...
# 6453  [0L, 10L, 6L, 5L, 4L, 7L, 11L, 5L, 6L, 11L, 4L...
# 6454  [0L, 9L, 12L, 4L, 7L, 10L, 7L, 7L, 6L, 7L, 7L,...
# 6455  [0L, 10L, 5L, 6L, 9L, 3L, 5L, 14L, 10L, 8L, 9L...
# 6456  [0L, 9L, 4L, 8L, 7L, 9L, 10L, 9L, 9L, 4L, 4L, ...
# 6457  [0L, 9L, 3L, 7L, 8L, 8L, 3L, 4L, 9L, 5L, 6L, 1...
# 6458  [0L, 6L, 7L, 5L, 3L, 7L, 6L, 5L, 3L, 3L, 6L, 1...
# 6459  [0L, 8L, 13L, 9L, 2L, 12L, 8L, 3L, 13L, 9L, 4L...
# 6460  [0L, 9L, 5L, 38L, 8L, 5L, 3L, 13L, 5L, 4L, 7L,...
# 6461  [0L, 8L, 8L, 9L, 11L, 12L, 4L, 8L, 6L, 8L, 3L,...
# 6462  [0L, 9L, 3L, 4L, 9L, 6L, 9L, 10L, 11L, 9L, 13L...
# 6463  [0L, 6L, 7L, 11L, 3L, 9L, 7L, 5L, 9L, 7L, 3L, ...
# 6464  [0L, 2L, 4L, 9L, 8L, 8L, 9L, 8L, 10L, 8L, 10L,...
# 6465  [0L, 13L, 4L, 6L, 10L, 5L, 8L, 6L, 9L, 9L, 3L,...
# 6466  [0L, 4L, 7L, 4L, 4L, 1L, 9L, 8L, 9L, 6L, 9L, 4...
# 6470  [0L, 11L, 10L, 4L, 3L, 6L, 10L, 9L, 4L, 11L, 7...
# 6471  [0L, 1L, 4L, 15L, 6L, 4L, 6L, 3L, 4L, 3L, 7L, ...
# 6472  [0L, 1L, 5L, 6L, 1L, 1L, 11L, 1L, 6L, 6L, 4L, ...
# 6473  [0L, 4L, 3L, 1L, 10L, 3L, 9L, 1L, 1L, 1L, 12L,...
#
# [2027 rows x 10 columns]

# %%
#winLose=df[(df['result'] =='Winner') | (df['result'] =='Loser')]
winLose=df[(df['username']=='boris') & ((df['result'] =='Winner') | (df['result'] =='Loser')) & ()]
winLose=np.sort(winLose['score'])

# %% [markdown]
# ## Performance for random coin flip strategy
#
# Let $c$ be the number of car advances by the computer, let $r$ be the number of car advances by a random coin flip strategy. $\max(c,r)=100$ and we are interested in the distribution of $r-c$.
#
# This process is a random walk with absorbing boundaries at $r=100$ and $c=100$
#
# Define a function $P(t,g)$ where $t=c+r$ and $g=r-c$.
#
# Clearly $r=\frac{g+t}{2}$ and $c=\frac{t-g}{2}$
#
# For a given value of $t$, $P(t,g)$ defines a probability over $g$.
#
# for $t=0$ we have $P(0,0)=1$ and $P(0,g)=0$ for $g \neq 0$
#
# for $t=1,2,..200$
#
# 1. $ P(t,g)= \frac{P(t-1,g+1)+P(t-1,g-1)}{2} $
# 2. **If**
#   * **Computer won:** $c=100$ -- $t-g=200$ -- $g=t-200$
#   * Or **Player won:** $r=100$ - $g+t=200$ - $g=200-t$
#   * **Then** set $F(g)=P(t,g)$ and afterwards set $P(t,g)=0$

# %%
from math import factorial
P=np.zeros([201,201])
F=np.zeros([201,1])

P[0,100]=1;

for t in range(1,201):
    for g in range(1,200):
        P[t,g]=(P[t-1,g-1]+P[t-1,g+1])/2.0;
        if t-(g-100)==200 or t+(g-100)==200:
            F[g]=P[t,g]
            P[t,g]=0
        
x=range(-100,101)
plot(x,cumsum(F))
print len(F),len(x)
# Out:
# 201 201

# %%
P[0:5,97:103]
# Out:
# array([[ 0.   ,  0.   ,  0.   ,  1.   ,  0.   ,  0.   ],
#        [ 0.   ,  0.   ,  0.5  ,  0.   ,  0.5  ,  0.   ],
#        [ 0.   ,  0.25 ,  0.   ,  0.5  ,  0.   ,  0.25 ],
#        [ 0.125,  0.   ,  0.375,  0.   ,  0.375,  0.   ],
#        [ 0.   ,  0.25 ,  0.   ,  0.375,  0.   ,  0.25 ]])

# %% [markdown]
# The bump at around 0 is because a draw ($g=0) is impossible in this game

# %% [markdown]
# ### Comparison with random strategy
# THe figures below show that humans almost always perform worse than random guessing.We ccome to this conclusion by comparing the comparing the empirical CDF with the CDF calculated for the strategy that generates 0,1 independently at random with probabilities 1/2,1/2.

# %%
L=len(winLose)
figure(figsize=[10,8])
plot(winLose,arange(0,1,1./L),x,cumsum(F))
grid()

# %%
figure(figsize=[10,8])
plot(winLose,arange(0,1,1./L),x,cumsum(F))
print winLose[-10:],L,1.0/L
xlim([10,60])
ylim([0.9,1])
grid()
# Out:
# [33 33 33 33 34 34 34 36 38 39] 1959 0.000510464522716

# %% [markdown]
# ### Outliers
# The cross-over between the graphs occurs at about 37. It is clear from this graph that the two highest scores 76 and 100, are probably cheats.
#
# It would be interesting to show the user where they are in terms of top percentile when compared with the other users, and when compared with the random strategy. Basically, the figure shows that scores higher than 45 are extremely unlikely if you are using a randomized strategy, so one can see it as evidence that you are doing better than random.
